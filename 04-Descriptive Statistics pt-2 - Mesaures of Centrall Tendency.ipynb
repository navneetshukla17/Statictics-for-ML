# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
maper = {'SepalLengthCm':'SL', 'SepalWidthCm':'SW', 'PetalLengthCm':'PL', 'PetalWidthCm':'PW'}
data.rename(columns=maper, inplace=True)

# %%
data.head()
# Out:
#    Id   SL   SW   PL   PW      Species
# 0   1  5.1  3.5  1.4  0.2  Iris-setosa
# 1   2  4.9  3.0  1.4  0.2  Iris-setosa
# 2   3  4.7  3.2  1.3  0.2  Iris-setosa
# 3   4  4.6  3.1  1.5  0.2  Iris-setosa
# 4   5  5.0  3.6  1.4  0.2  Iris-setosa

# %%
iris_setosa = data[data['Species'] == 'Iris-setosa']
iris_virginica = data[data['Species'] == 'Iris-virginica']
iris_versicolor = data[data['Species'] ==  'Iris-versicolor' ]

# %%
# Sepal Width
print(np.mean(iris_setosa['SW']))
print(np.mean(iris_versicolor['SW']))
print(np.mean(iris_virginica['SW']))
# Out:
# 3.418
# 2.7700000000000005
# 2.974

# %%
# Sepal Length
print(np.mean(iris_setosa['SL']))
print(np.mean(iris_versicolor['SL']))
print(np.mean(iris_virginica['SL']))
# Out:
# 5.006
# 5.936
# 6.587999999999998

# %%
# Petal Width
print(np.mean(iris_setosa['PW']))
print(np.mean(iris_versicolor['PW']))
print(np.mean(iris_virginica['PW']))
# Out:
# 0.244
# 1.3259999999999998
# 2.0260000000000002

# %%
# Petal Length
print(np.mean(iris_setosa['PL']))
print(np.mean(iris_versicolor['PL']))
print(np.mean(iris_virginica['PL']))
# Out:
# 1.464
# 4.26
# 5.5520000000000005

# %% [markdown]
# # The problem of `Outliers` !

# %%
# Range of Setosa Petal Length is between 1 to 2
plt.hist(iris_setosa['PL'])
# Out:
# (array([ 1.,  1.,  2.,  7., 12., 14.,  7.,  4.,  0.,  2.]),
#  array([1.  , 1.09, 1.18, 1.27, 1.36, 1.45, 1.54, 1.63, 1.72, 1.81, 1.9 ]),
#  <BarContainer object of 10 artists>)

# %%
# If we add an 'Outlier' of 50 at the end
np.mean(np.append(iris_setosa['PL'], 50))
# Out:
# 2.4156862745098038

# %% [markdown]
# ### As you can see, the mean of our iris_setosa column just doubled up due to that Outlier, So Never use `mean` when you have `Oultiers` in your dataset !

# %% [markdown]
# # The solution for `Outliers`: Median

# %% [markdown]
# ![68747470733a2f2f75706c6f61642e77696b696d656469612e6f72672f77696b6970656469612f636f6d6d6f6e732f7468756d622f632f63662f46696e64696e675f7468655f6d656469616e2e706e672f3132303070782d46696e64696e675f7468655f6d656469616e2e706e67.png](attachment:68747470733a2f2f75706c6f61642e77696b696d656469612e6f72672f77696b6970656469612f636f6d6d6f6e732f7468756d622f632f63662f46696e64696e675f7468655f6d656469616e2e706e672f3132303070782d46696e64696e675f7468655f6d656469616e2e706e67.png)

# %%
# Petal Length
print(np.median(iris_setosa['PL']))
print(np.median(iris_virginica['PL']))
print(np.median(iris_versicolor['PL']))
# Out:
# 1.5
# 5.55
# 4.35

# %% [markdown]
# ### The good thing about median

# %%
np.median(np.append(iris_setosa['PL'], 50))
# Out:
# 1.5

# %% [markdown]
# ### As you can see, like mean, median is more stable in the case of Outliers

# %%
arr = np.array([1, 4, 5, 8, 12, 600, 700, 800, 100000])
np.median(arr)
# Out:
# 12.0

# %% [markdown]
# # Mode

# %% [markdown]
# ![68747470733a2f2f7777772e6d61746873697366756e2e636f6d2f646174612f696d616765732f6d6f64652e737667.svg](attachment:68747470733a2f2f7777772e6d61746873697366756e2e636f6d2f646174612f696d616765732f6d6f64652e737667.svg)

# %%
from scipy import stats

print(stats.mode(iris_setosa['PL']))
print(stats.mode(iris_versicolor['PL']))
print(stats.mode(iris_virginica['PL']))
# Out:
# ModeResult(mode=1.5, count=14)
# ModeResult(mode=4.5, count=7)
# ModeResult(mode=5.1, count=7)
